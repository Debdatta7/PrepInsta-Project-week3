# %% [markdown]
# <a href="https://colab.research.google.com/github/Debdatta7/PrepInsta-Project/blob/main/data2_solutions_Debdatta_Mukherjee.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

data = pd.read_csv('/content/drive/MyDrive/Week 3 project/chipotle.tsv', sep="\t")

# %%
data
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price
# 0                                                   NaN     $2.39
# 1                                          [Clementine]     $3.39
# 2                                               [Apple]     $3.39
# 3                                                   NaN     $2.39
# 4     [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98
# ...                                                 ...        ...
# 4617  [Fresh Tomato Salsa, [Rice, Black Beans, Sour ...    $11.75
# 4618  [Fresh Tomato Salsa, [Rice, Sour Cream, Cheese...    $11.75
# 4619  [Fresh Tomato Salsa, [Fajita Vegetables, Pinto...    $11.25
# 4620  [Fresh Tomato Salsa, [Fajita Vegetables, Lettu...     $8.75
# 4621  [Fresh Tomato Salsa, [Fajita Vegetables, Pinto...     $8.75
#
# [4622 rows x 5 columns]

# %%
data.shape
# Out:
# (4622, 5)

# %%
data.describe
# Out:
# <bound method NDFrame.describe of       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price
# 0                                                   NaN     $2.39
# 1                                          [Clementine]     $3.39
# 2                                               [Apple]     $3.39
# 3                                                   NaN     $2.39
# 4     [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98
# ...                                                 ...        ...
# 4617  [Fresh Tomato Salsa, [Rice, Black Beans, Sour ...    $11.75
# 4618  [Fresh Tomato Salsa, [Rice, Sour Cream, Cheese...    $11.75
# 4619  [Fresh Tomato Salsa, [Fajita Vegetables, Pinto...    $11.25
# 4620  [Fresh Tomato Salsa, [Fajita Vegetables, Lettu...     $8.75
# 4621  [Fresh Tomato Salsa, [Fajita Vegetables, Pinto...     $8.75
#
# [4622 rows x 5 columns]>

# %%
data.isnull().sum()
# Out:
# order_id                 0
# quantity                 0
# item_name                0
# choice_description    1246
# item_price               0
# dtype: int64

# %%
data
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price
# 0                                                   NaN     $2.39
# 1                                          [Clementine]     $3.39
# 2                                               [Apple]     $3.39
# 3                                                   NaN     $2.39
# 4     [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98
# ...                                                 ...        ...
# 4617  [Fresh Tomato Salsa, [Rice, Black Beans, Sour ...    $11.75
# 4618  [Fresh Tomato Salsa, [Rice, Sour Cream, Cheese...    $11.75
# 4619  [Fresh Tomato Salsa, [Fajita Vegetables, Pinto...    $11.25
# 4620  [Fresh Tomato Salsa, [Fajita Vegetables, Lettu...     $8.75
# 4621  [Fresh Tomato Salsa, [Fajita Vegetables, Pinto...     $8.75
#
# [4622 rows x 5 columns]

# %%
data.choice_description
# Out:
# 0                                                     NaN
# 1                                            [Clementine]
# 2                                                 [Apple]
# 3                                                     NaN
# 4       [Tomatillo-Red Chili Salsa (Hot), [Black Beans...
#                               ...
# 4617    [Fresh Tomato Salsa, [Rice, Black Beans, Sour ...
# 4618    [Fresh Tomato Salsa, [Rice, Sour Cream, Cheese...
# 4619    [Fresh Tomato Salsa, [Fajita Vegetables, Pinto...
# 4620    [Fresh Tomato Salsa, [Fajita Vegetables, Lettu...
# 4621    [Fresh Tomato Salsa, [Fajita Vegetables, Pinto...
# Name: choice_description, Length: 4622, dtype: object

# %%
data.isnull().sum()
# Out:
# order_id                 0
# quantity                 0
# item_name                0
# choice_description    1246
# item_price               0
# dtype: int64

# %%
data.choice_description.fillna("unknown", inplace=True)
data
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price
# 0                                               unknown     $2.39
# 1                                          [Clementine]     $3.39
# 2                                               [Apple]     $3.39
# 3                                               unknown     $2.39
# 4     [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98
# ...                                                 ...        ...
# 4617  [Fresh Tomato Salsa, [Rice, Black Beans, Sour ...    $11.75
# 4618  [Fresh Tomato Salsa, [Rice, Sour Cream, Cheese...    $11.75
# 4619  [Fresh Tomato Salsa, [Fajita Vegetables, Pinto...    $11.25
# 4620  [Fresh Tomato Salsa, [Fajita Vegetables, Lettu...     $8.75
# 4621  [Fresh Tomato Salsa, [Fajita Vegetables, Pinto...     $8.75
#
# [4622 rows x 5 columns]

# %%
data.isnull().sum()
# Out:
# order_id              0
# quantity              0
# item_name             0
# choice_description    0
# item_price            0
# dtype: int64

# %%
data.choice_description = data.choice_description.str.replace("[", ' ')
# Out:
# <ipython-input-20-96766b4cdad4>:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   data.choice_description = data.choice_description.str.replace("[", ' ')

# %%
data
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price
# 0                                               unknown     $2.39
# 1                                           Clementine      $3.39
# 2                                                Apple      $3.39
# 3                                               unknown     $2.39
# 4      Tomatillo-Red Chili Salsa (Hot),  Black Beans...    $16.98
# ...                                                 ...        ...
# 4617   Fresh Tomato Salsa,  Rice, Black Beans, Sour ...    $11.75
# 4618   Fresh Tomato Salsa,  Rice, Sour Cream, Cheese...    $11.75
# 4619   Fresh Tomato Salsa,  Fajita Vegetables, Pinto...    $11.25
# 4620   Fresh Tomato Salsa,  Fajita Vegetables, Lettu...     $8.75
# 4621   Fresh Tomato Salsa,  Fajita Vegetables, Pinto...     $8.75
#
# [4622 rows x 5 columns]

# %%
data.choice_description = data.choice_description.str.replace("]", ' ')
# Out:
# <ipython-input-18-22c229ad36c7>:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   data.choice_description = data.choice_description.str.replace("]", ' ')

# %%
data
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price
# 0                                               unknown     $2.39
# 1                                           Clementine      $3.39
# 2                                                Apple      $3.39
# 3                                               unknown     $2.39
# 4      Tomatillo-Red Chili Salsa (Hot),  Black Beans...    $16.98
# ...                                                 ...        ...
# 4617   Fresh Tomato Salsa,  Rice, Black Beans, Sour ...    $11.75
# 4618   Fresh Tomato Salsa,  Rice, Sour Cream, Cheese...    $11.75
# 4619   Fresh Tomato Salsa,  Fajita Vegetables, Pinto...    $11.25
# 4620   Fresh Tomato Salsa,  Fajita Vegetables, Lettu...     $8.75
# 4621   Fresh Tomato Salsa,  Fajita Vegetables, Pinto...     $8.75
#
# [4622 rows x 5 columns]

# %%
data.dtypes
# Out:
# order_id               int64
# quantity               int64
# item_name             object
# choice_description    object
# item_price            object
# dtype: object

# %%
data.duplicated().sum()
# Out:
# 59

# %%
data.drop_duplicates(inplace=True)

# %%
data.duplicated().sum()
# Out:
# 0

# %%
data.quantity.max()
# Out:
# 15

# %%
data.quantity.min()
# Out:
# 1

# %%
data.item_price.max()
# Out:
# '$9.39 '

# %%
data.item_price.min()
# Out:
# '$1.09 '

# %%
data.choice_description.value_counts()
# Out:
# unknown                                                                                                                                          1228
#  Diet Coke                                                                                                                                        133
#  Coke                                                                                                                                             115
#  Sprite                                                                                                                                            77
#  Fresh Tomato Salsa,  Rice, Black Beans, Cheese, Sour Cream, Lettuce                                                                               41
#                                                                                                                                                  ...
#  Tomatillo Green Chili Salsa,  Sour Cream, Cheese, Guacamole, Rice, Fajita Vegetables                                                               1
#  Fresh Tomato Salsa (Mild),  Pinto Beans, Black Beans, Rice, Cheese, Sour Cream, Lettuce                                                            1
#   Fresh Tomato Salsa (Mild), Roasted Chili Corn Salsa (Medium), Tomatillo-Red Chili Salsa (Hot) ,  Pinto Beans, Cheese, Sour Cream, Lettuce         1
#  Fresh Tomato (Mild),  Guacamole, Rice, Black Beans                                                                                                 1
#  Tomatillo Green Chili Salsa,  Rice, Fajita Vegetables, Black Beans, Guacamole                                                                      1
# Name: choice_description, Length: 1044, dtype: int64

# %%
data.groupby(['item_name', 'choice_description'])['quantity'].sum().reset_index()
# Out:
#               item_name                                 choice_description  \
# 0     6 Pack Soft Drink                                              Coke
# 1     6 Pack Soft Drink                                         Diet Coke
# 2     6 Pack Soft Drink                                          Lemonade
# 3     6 Pack Soft Drink                                            Nestea
# 4     6 Pack Soft Drink                                            Sprite
# ...                 ...                                                ...
# 1866  Veggie Soft Tacos   Fresh Tomato Salsa,  Black Beans, Cheese, Sou...
# 1867  Veggie Soft Tacos   Fresh Tomato Salsa,  Fajita Vegetables, Rice,...
# 1868  Veggie Soft Tacos   Roasted Chili Corn Salsa (Medium),  Black Bea...
# 1869  Veggie Soft Tacos   Roasted Chili Corn Salsa,  Fajita Vegetables,...
# 1870  Veggie Soft Tacos   Tomatillo Red Chili Salsa,  Fajita Vegetables...
#
#       quantity
# 0           21
# 1           25
# 2            2
# 3            2
# 4            5
# ...        ...
# 1866         1
# 1867         1
# 1868         1
# 1869         1
# 1870         1
#
# [1871 rows x 3 columns]

# %%
data.groupby('order_id')['item_name'].nunique().reset_index()
# Out:
#       order_id  item_name
# 0            1          4
# 1            2          1
# 2            3          2
# 3            4          2
# 4            5          2
# ...        ...        ...
# 1829      1830          2
# 1830      1831          3
# 1831      1832          2
# 1832      1833          1
# 1833      1834          1
#
# [1834 rows x 2 columns]

# %%
data.item_name.value_counts()
# Out:
# Chicken Bowl                             717
# Chicken Burrito                          546
# Chips and Guacamole                      474
# Steak Burrito                            365
# Canned Soft Drink                        290
# Steak Bowl                               210
# Chips                                    208
# Bottled Water                            155
# Chicken Soft Tacos                       111
# Chips and Fresh Tomato Salsa             110
# Chicken Salad Bowl                       110
# Canned Soda                              102
# Side of Chips                            101
# Veggie Burrito                            95
# Barbacoa Burrito                          90
# Veggie Bowl                               85
# Carnitas Bowl                             68
# Barbacoa Bowl                             65
# Carnitas Burrito                          59
# Steak Soft Tacos                          55
# 6 Pack Soft Drink                         54
# Chicken Crispy Tacos                      47
# Chips and Tomatillo Red Chili Salsa       46
# Chips and Tomatillo Green Chili Salsa     43
# Carnitas Soft Tacos                       40
# Steak Crispy Tacos                        35
# Chips and Tomatillo-Green Chili Salsa     31
# Steak Salad Bowl                          29
# Nantucket Nectar                          27
# Barbacoa Soft Tacos                       25
# Chips and Roasted Chili Corn Salsa        22
# Izze                                      19
# Chips and Tomatillo-Red Chili Salsa       19
# Veggie Salad Bowl                         18
# Chips and Roasted Chili-Corn Salsa        18
# Barbacoa Crispy Tacos                     11
# Chicken Salad                              9
# Barbacoa Salad Bowl                        9
# Veggie Soft Tacos                          7
# Carnitas Crispy Tacos                      7
# Veggie Salad                               6
# Carnitas Salad Bowl                        6
# Burrito                                    6
# Steak Salad                                4
# Crispy Tacos                               2
# Salad                                      2
# Bowl                                       2
# Chips and Mild Fresh Tomato Salsa          1
# Veggie Crispy Tacos                        1
# Carnitas Salad                             1
# Name: item_name, dtype: int64

# %%
data
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price
# 0                                               unknown     $2.39
# 1                                           Clementine      $3.39
# 2                                                Apple      $3.39
# 3                                               unknown     $2.39
# 4      Tomatillo-Red Chili Salsa (Hot),  Black Beans...    $16.98
# ...                                                 ...        ...
# 4617   Fresh Tomato Salsa,  Rice, Black Beans, Sour ...    $11.75
# 4618   Fresh Tomato Salsa,  Rice, Sour Cream, Cheese...    $11.75
# 4619   Fresh Tomato Salsa,  Fajita Vegetables, Pinto...    $11.25
# 4620   Fresh Tomato Salsa,  Fajita Vegetables, Lettu...     $8.75
# 4621   Fresh Tomato Salsa,  Fajita Vegetables, Pinto...     $8.75
#
# [4563 rows x 5 columns]

# %%
data.item_price = data.item_price.str.replace('$',' ')
# Out:
# <ipython-input-34-fd6952bf2523>:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   data.item_price = data.item_price.str.replace('$',' ')

# %%
data.item_price
# Out:
# 0         2.39
# 1         3.39
# 2         3.39
# 3         2.39
# 4        16.98
#          ...
# 4617     11.75
# 4618     11.75
# 4619     11.25
# 4620      8.75
# 4621      8.75
# Name: item_price, Length: 4563, dtype: object

# %%
data.item_price = '$' + data.item_price.astype(str)

# %%
data.item_price = data.item_price.str.replace('$$',' ')
# Out:
# <ipython-input-37-52159556abb1>:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   data.item_price = data.item_price.str.replace('$$',' ')

# %%
data
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price
# 0                                               unknown   $ 2.39
# 1                                           Clementine    $ 3.39
# 2                                                Apple    $ 3.39
# 3                                               unknown   $ 2.39
# 4      Tomatillo-Red Chili Salsa (Hot),  Black Beans...  $ 16.98
# ...                                                 ...        ...
# 4617   Fresh Tomato Salsa,  Rice, Black Beans, Sour ...  $ 11.75
# 4618   Fresh Tomato Salsa,  Rice, Sour Cream, Cheese...  $ 11.75
# 4619   Fresh Tomato Salsa,  Fajita Vegetables, Pinto...  $ 11.25
# 4620   Fresh Tomato Salsa,  Fajita Vegetables, Lettu...   $ 8.75
# 4621   Fresh Tomato Salsa,  Fajita Vegetables, Pinto...   $ 8.75
#
# [4563 rows x 5 columns]

# %%
data['item_price'] = pd.to_numeric(data['item_price'].str.replace('$', ''))
# Out:
# <ipython-input-39-0c175d356e69>:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   data['item_price'] = pd.to_numeric(data['item_price'].str.replace('$', ''))

# %%
data
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description  item_price
# 0                                               unknown        2.39
# 1                                           Clementine         3.39
# 2                                                Apple         3.39
# 3                                               unknown        2.39
# 4      Tomatillo-Red Chili Salsa (Hot),  Black Beans...       16.98
# ...                                                 ...         ...
# 4617   Fresh Tomato Salsa,  Rice, Black Beans, Sour ...       11.75
# 4618   Fresh Tomato Salsa,  Rice, Sour Cream, Cheese...       11.75
# 4619   Fresh Tomato Salsa,  Fajita Vegetables, Pinto...       11.25
# 4620   Fresh Tomato Salsa,  Fajita Vegetables, Lettu...        8.75
# 4621   Fresh Tomato Salsa,  Fajita Vegetables, Pinto...        8.75
#
# [4563 rows x 5 columns]

# %%
data['item_price'] =  '$' + data['item_price'].astype(str)

# %%
data
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price
# 0                                               unknown      $2.39
# 1                                           Clementine       $3.39
# 2                                                Apple       $3.39
# 3                                               unknown      $2.39
# 4      Tomatillo-Red Chili Salsa (Hot),  Black Beans...     $16.98
# ...                                                 ...        ...
# 4617   Fresh Tomato Salsa,  Rice, Black Beans, Sour ...     $11.75
# 4618   Fresh Tomato Salsa,  Rice, Sour Cream, Cheese...     $11.75
# 4619   Fresh Tomato Salsa,  Fajita Vegetables, Pinto...     $11.25
# 4620   Fresh Tomato Salsa,  Fajita Vegetables, Lettu...      $8.75
# 4621   Fresh Tomato Salsa,  Fajita Vegetables, Pinto...      $8.75
#
# [4563 rows x 5 columns]

# %%
data.to_csv('cleaned_chipotle.csv', sep=',')

# %%
data
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price
# 0                                               unknown      $2.39
# 1                                           Clementine       $3.39
# 2                                                Apple       $3.39
# 3                                               unknown      $2.39
# 4      Tomatillo-Red Chili Salsa (Hot),  Black Beans...     $16.98
# ...                                                 ...        ...
# 4617   Fresh Tomato Salsa,  Rice, Black Beans, Sour ...     $11.75
# 4618   Fresh Tomato Salsa,  Rice, Sour Cream, Cheese...     $11.75
# 4619   Fresh Tomato Salsa,  Fajita Vegetables, Pinto...     $11.25
# 4620   Fresh Tomato Salsa,  Fajita Vegetables, Lettu...      $8.75
# 4621   Fresh Tomato Salsa,  Fajita Vegetables, Pinto...      $8.75
#
# [4563 rows x 5 columns]

# %%
data.choice_description = data.choice_description.str.replace('Unknown','None')

# %%
data.choice_description.str.split(",",expand= True)
# Out:
#                                      0                    1             2  \
# 0                              unknown                 None          None
# 1                          Clementine                  None          None
# 2                               Apple                  None          None
# 3                              unknown                 None          None
# 4      Tomatillo-Red Chili Salsa (Hot)          Black Beans          Rice
# ...                                ...                  ...           ...
# 4617                Fresh Tomato Salsa                 Rice   Black Beans
# 4618                Fresh Tomato Salsa                 Rice    Sour Cream
# 4619                Fresh Tomato Salsa    Fajita Vegetables   Pinto Beans
# 4620                Fresh Tomato Salsa    Fajita Vegetables     Lettuce
# 4621                Fresh Tomato Salsa    Fajita Vegetables   Pinto Beans
#
#                 3              4             5             6     7     8     9
# 0            None           None          None          None  None  None  None
# 1            None           None          None          None  None  None  None
# 2            None           None          None          None  None  None  None
# 3            None           None          None          None  None  None  None
# 4          Cheese   Sour Cream            None          None  None  None  None
# ...           ...            ...           ...           ...   ...   ...   ...
# 4617   Sour Cream         Cheese       Lettuce   Guacamole    None  None  None
# 4618       Cheese        Lettuce   Guacamole            None  None  None  None
# 4619    Guacamole      Lettuce            None          None  None  None  None
# 4620         None           None          None          None  None  None  None
# 4621    Lettuce             None          None          None  None  None  None
#
# [4563 rows x 10 columns]

# %%
split_columns = data['choice_description'].str.split(",", expand=True)


split_columns.columns = ['choice_description_1', 'choice_description_2', 'choice_description_3',
                         'choice_description_4', 'choice_description_5', 'choice_description_6',
                         'choice_description_7', 'choice_description_8', 'choice_description_9',
                         'choice_description_10']


data_frame = pd.concat([data, split_columns], axis=1)

# %%
data_frame
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price  \
# 0                                               unknown      $2.39
# 1                                           Clementine       $3.39
# 2                                                Apple       $3.39
# 3                                               unknown      $2.39
# 4      Tomatillo-Red Chili Salsa (Hot),  Black Beans...     $16.98
# ...                                                 ...        ...
# 4617   Fresh Tomato Salsa,  Rice, Black Beans, Sour ...     $11.75
# 4618   Fresh Tomato Salsa,  Rice, Sour Cream, Cheese...     $11.75
# 4619   Fresh Tomato Salsa,  Fajita Vegetables, Pinto...     $11.25
# 4620   Fresh Tomato Salsa,  Fajita Vegetables, Lettu...      $8.75
# 4621   Fresh Tomato Salsa,  Fajita Vegetables, Pinto...      $8.75
#
#                   choice_description_1 choice_description_2  \
# 0                              unknown                 None
# 1                          Clementine                  None
# 2                               Apple                  None
# 3                              unknown                 None
# 4      Tomatillo-Red Chili Salsa (Hot)          Black Beans
# ...                                ...                  ...
# 4617                Fresh Tomato Salsa                 Rice
# 4618                Fresh Tomato Salsa                 Rice
# 4619                Fresh Tomato Salsa    Fajita Vegetables
# 4620                Fresh Tomato Salsa    Fajita Vegetables
# 4621                Fresh Tomato Salsa    Fajita Vegetables
#
#      choice_description_3 choice_description_4 choice_description_5  \
# 0                    None                 None                 None
# 1                    None                 None                 None
# 2                    None                 None                 None
# 3                    None                 None                 None
# 4                    Rice               Cheese         Sour Cream
# ...                   ...                  ...                  ...
# 4617          Black Beans           Sour Cream               Cheese
# 4618           Sour Cream               Cheese              Lettuce
# 4619          Pinto Beans            Guacamole            Lettuce
# 4620            Lettuce                   None                 None
# 4621          Pinto Beans            Lettuce                   None
#
#      choice_description_6 choice_description_7 choice_description_8  \
# 0                    None                 None                 None
# 1                    None                 None                 None
# 2                    None                 None                 None
# 3                    None                 None                 None
# 4                    None                 None                 None
# ...                   ...                  ...                  ...
# 4617              Lettuce          Guacamole                   None
# 4618          Guacamole                   None                 None
# 4619                 None                 None                 None
# 4620                 None                 None                 None
# 4621                 None                 None                 None
#
#      choice_description_9 choice_description_10
# 0                    None                  None
# 1                    None                  None
# 2                    None                  None
# 3                    None                  None
# 4                    None                  None
# ...                   ...                   ...
# 4617                 None                  None
# 4618                 None                  None
# 4619                 None                  None
# 4620                 None                  None
# 4621                 None                  None
#
# [4563 rows x 15 columns]
